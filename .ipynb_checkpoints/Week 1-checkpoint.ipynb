# %%
grade=input()

if grade == "A":
    print("Congratulations!")
elif grade == "B":
    print("Good")
elif grade == "C":
    print("Pass")
else:
    print("No such grade in the system")
# Out:
# A
# Congratulations!

# %%
print(type(grade))
# Out:
# <class 'str'>

# %%
grade=int(input())

if grade == "A":
    print("Congratulations!")
elif grade == "B":
    print("Good")
elif grade == "C":
    print("Pass")
else:
    print("No such grade in the system")
# Out:
# 100
# No such grade in the system

# %%
print(type(grade))
# Out:
# <class 'int'>
